# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import matplotlib.pyplot as plt

from matplotlib import pyplot as plt

image_path = '/content/drive/MyDrive/pattern_exam/formal.jpg'

image = Image.open(image_path)

plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image_path = '/content/drive/MyDrive/pattern_exam/formal.jpg'

image = Image.open(image_path)

# Display image
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
# from PIL import Image
# import matplotlib.pyplot as plt

# # Load image
# image_path = "/content/drive/MyDrive/pattern_exam/formal.jpg"
# image = Image.open(image_path)

# # Crop image (adjust the coordinates as needed)
# crop_box = (100, 100, 500, 500)  # Example crop box coordinates (left, top, right, bottom)
# cropped_image = image.crop(crop_box)

# # Display cropped image
# plt.imshow(cropped_image)
# plt.axis('off')
# plt.show()


import cv2
path = "/content/drive/MyDrive/pattern_exam/formal.jpg"

img = cv2.imread(path)

x, y, w, h = 40, 50, 50, 40

cropped = img[y:y+h, x:x+w]

plt.imshow(cv2.cvtColor(cropped, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Rotate image (replace 45 with your desired angle)
rotated_image = image.rotate(90)

# Display rotated image
plt.imshow(rotated_image)
plt.axis('off')
plt.show()

# %%
# !pip install rembg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 70.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 14.1 MB/s eta 0:00:00
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
from rembg import remove

image_path = '/content/drive/MyDrive/pattern_exam/formal.jpg'
image = Image.open(image_path)

rem_img = remove(image)
# original_image = Image.open(image_path)

# # Convert the original image to RGBA format
# img = original_image.convert("RGBA")

# # Remove the background using the rembg library
# output_image = remove(img, alpha_threshold=0.0, bg_color=(255, 255, 255))

# Display the original and background-removed images
plt.subplot(1, 2, 1)
plt.imshow(rem_img)
plt.title("rmv image")
plt.axis('off')

# plt.subplot(1, 2, 2)
# plt.imshow(output_image)
# plt.title("Background Removed Image")
# plt.axis('off')

# plt.show()
# Out:
# (-0.5, 5808.5, 4090.5, -0.5)

# %%
# from PIL import Image
# import matplotlib.pyplot as plt

# # Load the image
# image_path = "/content/drive/MyDrive/pattern_exam/formal_image3.jpg"
# image = Image.open(image_path)

# # Get image size and shape
# image_size = image.size
# image_shape = image.size + (len(image.getbands()),)

# # Print image size and shape
# print(f"Image Size: {image_size}")
# print(f"Image Shape: {image_shape}")

# # Show the image
# plt.imshow(image)
# plt.axis('off')
# plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

image_path = '/content/drive/MyDrive/pattern_exam/formal_image3.jpg'

image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
threshold_value = 128

_, threshold_image = cv2.threshold(image, threshold_value,255, cv2.THRESH_BINARY)

plt.subplot(1,2,1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

plt.subplot(1,2,2)
plt.imshow(threshold_image, cmap='gray')
plt.title("Threshold Image")

plt.show()

# %%
# remove bg
rem_bg = remove(image)
